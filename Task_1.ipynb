# %% [markdown]
# Task_1
#
# 1.  Write an SQL query to fetch “FIRST_NAME” from the Worker table using
#     the alias name as \<WORKER_NAME\>.
#
# > <img src="attachment:vertopal_e681142122444e46a124cc010733e1fa/media/image1.png" style="width:6.26806in;height:3.17986in" />
#
# 1.  Write an SQL query to fetch unique values of DEPARTMENT from the
#     Worker table.
#
# > <img src="attachment:vertopal_e681142122444e46a124cc010733e1fa/media/image2.png" style="width:6.26806in;height:3.20556in" />
#
# 1.  Write an SQL query to show the last 5 records from a table.
#
# > <img src="attachment:vertopal_e681142122444e46a124cc010733e1fa/media/image3.png" style="width:6.26806in;height:3.17986in" />
