# %% [markdown]
# Task_1
#
# 1.Write an SQL query to fetch “FIRST_NAME” from the Worker table using
#
# > the alias name as \<WORKER_NAME\>.
# >
# > <img src="attachment:vertopal_76c18a796e594f49bea4323a6a5a91fc/media/image1.png" style="width:6.26805in;height:3.18055in" />
# >
# > 2.Write an SQL query to fetch unique values of DEPARTMENT from the
# >
# > Worker table.
# >
# > <img src="attachment:vertopal_76c18a796e594f49bea4323a6a5a91fc/media/image2.png" style="width:6.26805in;height:3.20556in" />
# >
# > 3.Write an SQL query to show the last 5 records from a table.
# >
# > <img src="attachment:vertopal_76c18a796e594f49bea4323a6a5a91fc/media/image3.png" style="width:6.26805in;height:3.18056in" />
